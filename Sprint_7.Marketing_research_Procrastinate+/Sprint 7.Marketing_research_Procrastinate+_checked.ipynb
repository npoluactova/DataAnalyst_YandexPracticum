# %% [markdown]
# **Наталия, привет!**
#
# Меня зовут Алексей Каргин, я буду проверять проект **Анализ бизнес-показателей**. Приятно познакомиться! Предлагаю общаться на «ты». Если это неприемлемо, будет здорово, если я об этом узнаю, и мы перейдем на «вы». Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их отработки проект не будет принят. Проверяя проект, я буду делать акцент не только на его решение и выполнение всех необходимых пунктов, но и на интерпретацию результата.
# </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации. Постарайся учесть эти комментарии в этом проекте, а также взять что-то на будущее.
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая общие рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info">
# <b>Комментарий студента</b>
#
# Например, вот так. Также в таких блоках у меня можно спросить то, что осталось неясным.
# </div>
#
# ---
#
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋 Наталия, спасибо, что прислала проект! У тебя вышла хорошая работа - код написан корректно; функции из материалов спринта использованы верно; а сам проект имеет хорошее оформление. Если смотреть в общем - то ты корректно интерпретировала полученные результаты. <span class="text-danger"> Но, к сожалению, в проекте есть несколько пунктов, которые нужно добавить или детализировать.</span>
#
# Посмотри, пожалуйста, мои дополнительные комментарии. Мне кажется, у тебя не составит труда исправить быстро и качественно. Буду ждать вторую версию проекта.
#
#
# <br>
# С наилучшими пожеланиями, <br>
# Алексей
# </div>
#
# ---

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Привет! Большое спасибо за комментарии и замечания. Исправила все, что смогла, надеюсь, на этот раз выводы будут ближе к истине :)
# </div>
#
#
# ---
#
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋 Наталия, спасибо, что внесла необходимые изменения в проект. Теперь все выглядит корректно, а сам проект может быть принят! Посмотри, пожалуйста, подробности в новых комментариях (v.2). Поздравляю с завершением, на мой взгляд, одной из самых сложных тем обучения - основные метрики освоены, функции интегрированы верно. Отдельное спасибо за обратную связь на мои комментарии и за то, что удобно оформила все изменения - это повысило продуктивность повторной проверки, и, вообще, является хорошим стилем коммуникации с будущими коллегами!
#
# Желаю продуктивного и интересного дальнешейго обучения!
#
# <br>
# С наилучшими пожеланиями, <br>
# Алексей
# </div>
#
# ---

# %% [markdown]
# ## Исследование окупаемости рекламы для приложения Procrastinate Pro+

# %% [markdown]
# Необходимо провести исследование окупаемости рекламы для приложения Procrastinate Pro+. Последние месяцы компания терпит убытки, необходимо разобраться в причинах и определить дальнейшие шаги для исправления ситуации. <br>
# Требуется проанализировать данные о сессиях и покупках пользователей, привлечённых с 1 мая по 27 октября 2019 года, а так же рекламные расходы за указанный период.
#
# **Цель исследования:** <br>
# Оценить окупаемость рекламы Procrastinate Pro+. Для этого необходимо оценить расходы на привлечение пользователей в разрезе различных показателей (каналов, устройств, стран) и определить сколько денег приносит каждый клиент.
#
# **Ход исследования** <br>
# 1. Изучить данные сессий и покупок пользователей приложения.
# 2. Написать функции для расчета и визуализации LTV, ROI, конверсии и удержания.
# 3. Составить профиль пользователя: устройство подключения, регион использования и канал, откуда пользователь пришел.
# 4. Изучение динамики рекламных расходов. Определение рекламных затрат по каждому из каналов привлечения и расчет средней стоимости привлечения одного пользователя для каждого канала.
# 5. Расчет LTV, ROI, CAC, конверсии, удержания. Выявление перечня проблем, приведших к убыткам компании.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Хорошо, что проект начинается с небольшого введения из которого понятно, что будет выполнено в проекте и какие задачи будут решены.
# </div>

# %% [markdown]
# ### Загрузите данные и подготовьте их к анализу

# %% [markdown]
# Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 С одной стороны понятно, что это проект учебный и в нем есть шаблон, но, с другой стороны, шаблон лучше адаптировать под проект. Например, вместо "Загрузите данные и подготовьте их к анализу" указать название блока как "Загрузка  и подготовка данных к анализу" и тп. Это будет важным моментом при подготовке проектов для своего портфолио.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Поняла, спасибо за совет. Иногда переписывать все не хочется, т.к. к моменту отправки на ревью уже нет сил, но буду с ленью бороться :)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Спасибо, что объяснила ситуацию :) Постарайся скорректировать вводную часть, если будешь использовать проект в качестве портфолио - это его выделит с положительно.
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Хорошо, когда все импорты находятся в первой ячейке кода, это соответствует стилю [PEP8](https://www.python.org/dev/peps/pep-0008/) и помогает понять, какое окружение необходимо для запуска проекта.
# </div>

# %%
try:
    visits, orders, costs = (
        pd.read_csv('/datasets/visits_info_short.csv'),  # лог сервера с данными о посещениях
        pd.read_csv('/datasets/orders_info_short.csv'),  # выгрузка покупок
        pd.read_csv('/datasets/costs_info_short.csv')  # рекламные расходы
)
except:
    visits, orders, costs = (
        pd.read_csv('https://code.s3.yandex.net/datasets/visits_info_short.csv'),
        pd.read_csv('https://code.s3.yandex.net/datasets/orders_info_short.csv'),
        pd.read_csv('https://code.s3.yandex.net/datasets/costs_info_short.csv')
    )

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Отлично, что используешь альтернативные пути к данным, только посмотри, пожалуйста, чтобы в загрузке не было "лишних" данных, например, `data = pd.read_csv('/datasets/games.csv')`.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Пардон, копипаста из прошлого проекта. Спасибо, что заметил, удалила. :)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Спасибо, что подправила этот момент :)
# </div>

# %%
display('visits table')
display(visits.head())
display('orders table')
display(orders.head())
display('costs table')
display(costs.head())
# Out:
# 'visits table'
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
# 'orders table'
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# 'costs table'
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# ...

# %% [markdown]
# Изучим детально структуру каждой из таблиц.

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Видно, что пропусков в данных нет. Проверим наличие дублей.

# %%
display(visits.duplicated().sum(), orders.duplicated().sum(), costs.duplicated().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# Дублей в данных так же нет.
#
# Приведем имена атрибутов к единому формату: все пробелы заменим на "_" и приведем к нижнему регистру.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 По этим пунктам все корректно - данные хорошего качества. Здорово, что проверяешь входящие данные на возможные ошибки - пропуски и полные дубликаты это, можно сказать, обязательные проверки для любых данных.
# </div>

# %%
visits.columns = visits.columns.str.replace(' ', '_').str.lower()
orders.columns = orders.columns.str.replace(' ', '_').str.lower()
costs.columns = costs.columns.str.replace(' ', '_').str.lower()

# %%
display(visits.columns,
orders.columns,
costs.columns)
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Отличное решение перевести названия столбцов к змеиному регистру. Также отмечу отличное исполнение - ничего лишнего, все в одно действие.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Спасибо!
# </div>

# %% [markdown]
# Изменим типы данных для атрибутов, содержащих даты.

# %%
try:
    visits['session_start'] = pd.to_datetime(visits['session_start'])
    visits['session_end'] = pd.to_datetime(visits['session_end'])
    orders['event_dt'] = pd.to_datetime(orders['event_dt'])
    costs['dt'] = pd.to_datetime(costs['dt']).dt.date     
except:
    print('Ошибка преобразования типов данных')

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Отличная работа на этой стадии! Данные были успешно загружены и подготовлены для дальнейшего анализа: скорректированы типы данных, изменены названия столбцов, проверены пропуски и дубликаты.
#
# ---
#
# 📝 В качестве рекомендации (здесь и к другим проектам в будущем). На стадии загрузки и подготовки данных к исследовательскому анализу, советую посмотреть на данные более детально, не только на неявные дубликаты (что было сделано отлично), но и на другие особенности. Чем большем мы знаем о данных - тем более корректными и обоснованными выглядят наши выводы. Такие проверки много времени не занимают, но зато мы можем лучше контролировать данные и их анализ (конечно, мы так или иначе это проверим уже на стадии анализа данных, но лучше заранее познакомиться с данными). Например, мы можем:
# - проверить временные интервалы на соответствие условию проекта, а также на возможные ошибки;
# - проверить категориальные данные на ошибки (например, неявные дубликаты);
# - для численных данных посмотреть на их статистические показатели и проверить их на наличие каких-то ошибок или аномалий (например, нули или отрицательные значения там, где они не должны быть).
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера v.1</b>
#
# 📝 Также советую в конце раздела коротко резюмировать информацию о данных и их объеме в виде небольшого промежуточного вывода.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Благодарю, приняла к сведению оба комментария. Ниже привела краткое резюме о данных.
# </div>

# %% [markdown]
# Проверим, за какие периоды представлены входные данные.

# %%
display(visits['session_start'].min(), visits['session_start'].max())
# Out:
# Timestamp('2019-05-01 00:00:41')
# Timestamp('2019-10-31 23:59:23')

# %%
display(orders['event_dt'].min(), orders['event_dt'].max())
# Out:
# Timestamp('2019-05-01 00:28:11')
# Timestamp('2019-10-31 23:56:56')

# %%
display(costs['dt'].min(), costs['dt'].max())
# Out:
# datetime.date(2019, 5, 1)
# datetime.date(2019, 10, 27)

# %%
len(costs['dt'].unique())
# Out:
# 180

# %%
#проверим, для каждого ли канала tcnm информация о затратах в каждую из исследуемых дат
costs.groupby('channel')['dt'].agg('count')
# Out:
# channel
# AdNonSense            180
# FaceBoom              180
# LeapBob               180
# MediaTornado          180
# OppleCreativeMedia    180
# RocketSuperAds        180
# TipTop                180
# WahooNetBanner        180
# YRabbit               180
# lambdaMediaAds        180
# Name: dt, dtype: int64

# %% [markdown]
# Исходные данные были предобработаны для проведения дальнейшего анализа: скорректированы типы данных, изменены названия столбцов, проверены пропуски и дубликаты. <br>
#
# Таблица с визитами пользователей visits содержит 309901 запись, с данными о посещениях приложения в период с 01 мая 2019 года по 31 октября 2019 года. Данные о заказах orders доступны так же за аналогичный период и представлены в объеме 40212 записей.
#
# Информация о рекламных расходах в таблице costs доступна только за период с 01 мая 2019 по 27 октября 2019 года, что совпадает с периодом исследования, который обозначил заказчик. В таблице 1800 записей, для каждого канала привлечения клиента указаны расходы в каждую из исследуемых дат.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Спасибо, что детализировала эту часть. Еще можно было бы проверить по пользователям - были ли даты окончания сессии раньше, чем ее начало, и были ли отрицательные значения в затратах и покупках (спойлер - в этих данных все корректно, но как рекомендация - при работе с реальными данными лучше это проверить).
#
# </div>

# %% [markdown]
# ### Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

 
    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 📝 Обрати, пожалуйста, внимание на эту функцию - она просит названия событий, но дальше этот параметр не используется в самой функции.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Действительно, лишний параметр. Удалила.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Спасибо, что проверила этот момент.
#
# </div>

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Отлично! Необходимые функции были заданы корректно.
# </div>

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %% [markdown]
# Сформируем профили пользователей. <br>
# Для каждого пользователя добавим признак payer (признак плательщика) и определим стоимость расходов на его привлечение.
# Так же определим, минимальную и максимальную дату привлечения пользователей на основании данных о расходах на рекламные кампании из таблицы costs.

# %%
# получаем профили пользователей
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
min_acquisition_date = profiles['dt'].min()
print("Минимальная дата привлечения пользователей ", min_acquisition_date)
# Out:
# Минимальная дата привлечения пользователей  2019-05-01

# %%
max_acquisition_date = profiles['dt'].max()
print("Максимальная дата привлечения пользователей ", max_acquisition_date)
# Out:
# Максимальная дата привлечения пользователей  2019-10-27

# %% [markdown]
# Полученные минимальная и максимальная даты привлечения пользователей совпадают с периодом исследования.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Профили пользователей созданы корректно, изучены минимальные и максимальные даты их привлечения.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера v.1</b>
#
# 📝 Тут можно было бы дать небольшой комментарий по полученным значениям, например, насколько они соответствуют условиям проекта.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Добавила выше небольшой комментарий.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Спасибо!
#
# </div>

# %% [markdown]
# Изучим профили пользователей в разрезе регионов, чтобы определить:
# - перечень стран, из которых пользователи приходят в приложение;
# - на какую страну приходится больше всего платящих пользователей;
# - соотношение платящих и неплатящих пользователей для каждой страны.

# %%
(profiles.groupby('region')
 .agg({'user_id':'nunique', 'payer':'mean'})
 .rename(columns={'user_id': 'user_cnt', 'payer': 'payer_ratio'})
 .sort_values(by = 'payer_ratio', ascending = False))
# Out:
#                user_cnt  payer_ratio
# region
# United States    100002     0.069019
# Germany           14981     0.041119
# UK                17575     0.039829
# France            17450     0.037994

# %% [markdown]
# Страны, из которых пользователи пользуются приложением,  - это США, Германия, Великобритания и Франция. <br>
# Наибольшее количество платящих пользователей приходится на США - 6.9%. Так же из США привлечено в целом наибольшее количество пользователей (2/3), в разы больше, чем из других стран.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Все верно - наиболее платящие пользователи приходят из `США` - региона, которые является главным сегментом нашего рынка. Если пользователи не будут окупаться - то мы уже понимаем, на какой регион обратить внимание в первую очередь.
# </div>

# %% [markdown]
# Изучим профили пользователей в разрезе устройств, чтобы определить:
# - с каких устройств клиенты пользуются приложением;
# - какие устройства предпочитают платящие пользователи;
# - соотношение платящих и неплатящих пользователей для каждого устройства.

# %%
(profiles.groupby('device')
 .agg({'user_id':'nunique', 'payer':'mean'})
 .rename(columns={'user_id': 'user_cnt', 'payer': 'payer_ratio'})
 .sort_values(by = 'payer_ratio', ascending = False))
# Out:
#          user_cnt  payer_ratio
# device
# Mac         30042     0.063644
# iPhone      54479     0.062079
# Android     35032     0.058518
# PC          30455     0.050468

# %% [markdown]
# Среди пользователей Procrastinate Pro+, большая часть пользователей - владельцы iPhone. Наибольшее количество платящих пользователей приходятся на устройства Mac и iPhone ~6,2-6,3%.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Тут тоже все верно! Видимо, устройства  `Apple` наиболее всего удобны для просмотра контента и его оплаты.
# </div>

# %% [markdown]
# Изучим профили пользователей в разрезе источников привлечения, чтобы определить:
# - каналы привлечения пользователей;
# - каналы, из которых пришло больше всего платящих пользователей;
# - соотношение платящих и неплатящих пользователей для каждого канала привлечения.

# %%
(profiles.groupby('channel')
 .agg({'user_id':'nunique', 'payer':'mean'})
 .rename(columns={'user_id': 'user_cnt', 'payer': 'payer_ratio'})
 .sort_values(by = 'payer_ratio', ascending = False))
# Out:
#                     user_cnt  payer_ratio
# channel
# FaceBoom               29144     0.122049
# AdNonSense              3880     0.113402
# lambdaMediaAds          2149     0.104700
# TipTop                 19561     0.096007
# RocketSuperAds          4448     0.079137
# WahooNetBanner          8553     0.052964
# YRabbit                 4312     0.038265
# MediaTornado            4364     0.035747
# LeapBob                 8553     0.030633
# OppleCreativeMedia      8605     0.027077
# organic                56439     0.020553

# %% [markdown]
# Большая часть пользователей поступила из канала organic, т.е. нашли приложение самостоятельно. Следующие по количеству привлеченных пользователей каналы - это FaceBoom и TipTop. <br>
# При этом наибольшая доля платящих пользователей приходится на канал FaceBoom - 12,2%, когда organic наоборот характеризуется наименьшим количеством платящих пользователей.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Все корректно. В целом выводы можно расширить - смотри, у нас есть пул источников с неплохой долей платящих пользователей. Это не только `FaceBoom`, но и `AdNonSense`, `lambdaMediaAds` и  `TipTop`. При этом у нас есть часть источников, которые по доле платящих пользователей приближаются к органическому трафику. Остается два источника, которые занимаю промежуточное положение.
#
#
# ---
#
# 📝 Также хотел оставить несколько рекомендаций по альтернативному решению задачи выше:
# 1. когда мы делаем одни и тебе вычисления на разных данных - можно сделать одну функцию, которая будет выводить нужные данные;
# 2. мы можем использовать дополнительное форматирование колонок, для более информативного отображения информации.
#
# Еще в примере ниже посмотри, пожалуйста, как мы можем назначать названия колонок в методе `agg()`
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Спасибо! Без rename() точно элегантнее код выглядит.Про функцию так же поняла, учту. <br>
# У меня следующий вопрос. Я вчера долго размышляла о том, а не надо ли было в этой задаче как-то категоризировать каналы?
# Их 10 шт, и действительно, некоторые по доходности/долям пользователей можно было бы объединить в одну группу.
# Стоило ли проводить такую манипуляцию? Или это бессмысленно, т.к. одна из целей исследования - детально рассмотреть каждый канал?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Тут правда где-то по середине :) С одной стороны, в рамках этого проекта это и не требуется, так как действительно, дальше смотрим на данные детально. Но, я бы рекомендовал для себя отмечать такие моменты - например, по региону - можно сразу отметить, что есть США и все остальные регионы. При этом остальные регионы ниже по пользователям, но между собой примерно на одном уровне - возможно происходит "прощупывание" других сегментов рынка. Тоже самое по устройствам - можно для себя отметить несколько категорий - есть лидеры, есть плюс-минус средние и на уровне органических пользователей. Сразу возникает вопрос - зачем нам привлекать пользователей, которые не отличаются от органических. И так далее.
#
# Поэтому, как мне кажется, с опытом приходит понимание, где нужно категорировать данные, где можно обойтись и без этого. Т.е. тут я бы не заморачивался с какой-то детальной категоризацией, но для себя обозначил бы группы источников.
#
# Еще в этом блоке - можно было бы посмотреть, как источники распределены по регионам и устройствам.
#
#
#
# </div>

# %%
# ячейка ревьюера:
(profiles
 .groupby('device').agg(total_users = ('payer','count'),
                        payer_sahre = ('payer','mean'))
 .reset_index()
 .sort_values(by=('payer_sahre'), ascending=False)
 .style.format({('payer_sahre'): '{:.2%}'})
)
# Out:
# <style  type="text/css" >
# </style><table id="T_56160_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >device</th>        <th class="col_heading level0 col1" >total_users</th>        <th class="col_heading level0 col2" >payer_sahre</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_56160_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_56160_row0_col0" class="data row0 col0" >Mac</td>
#                         <td id="T_56160_row0_col1" class="data row0 col1" >30042</td>
#                         <td id="T_56160_row0_col2" class="data row0 col2" >6.36%</td>
#             </tr>
#             <tr>
#                         <th id="T_56160_level0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_56160_row1_col0" class="data row1 col0" >iPhone</td>
# ...

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %%
print("Общая сумма расходов на маркетинг за все время = ", costs['costs'].sum())
# Out:
# Общая сумма расходов на маркетинг за все время =  105497.30000000002

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Все верно.
#
# </div>

# %% [markdown]
# Рассчитаем затраты на маркетинг по каждому рекламному источнику.

# %%
costs_channel = costs.groupby('channel').agg({'costs':'sum'}).sort_values(by = 'costs', ascending = False)
costs_channel['costs, %'] = costs_channel['costs']/costs['costs'].sum()*100
costs_channel
# Out:
#                        costs   costs, %
# channel
# TipTop              54751.30  51.898295
# FaceBoom            32445.60  30.754910
# WahooNetBanner       5151.00   4.882589
# AdNonSense           3911.25   3.707441
# OppleCreativeMedia   2151.25   2.039152
# RocketSuperAds       1833.00   1.737485
# LeapBob              1797.60   1.703930
# lambdaMediaAds       1557.60   1.476436
# MediaTornado          954.48   0.904744
# YRabbit               944.22   0.895018

# %% [markdown]
# Большо всего денег на рекламу было потрачено на канал TipTop - 52% от общих затрат. Следующий по затратам - это канал FaceBoom с 31% от общих затрат.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Тут тоже все корректно! Здорово, что были рассчитана доля затрат по каждому источнику. Хорошо видно, что на два первых источника было потрачено более 82% бюджета. Поэтому мы можем уже на этом этапе отметить, что если реклама не будет окупаться, то на эти два источника нужно обратить более пристальное внимание.
#
# </div>

# %% [markdown]
# Визуализируем динамику изменения расходов во времени по каждому источнику.

# %%
#анализируем данные с мая 2019 по октябрь 2019, поэтому номера месяца достаточно для уникальности (без года)
costs['week'] = (pd.to_datetime(costs['dt']).dt.isocalendar().week)
costs['month'] = (pd.to_datetime(costs['dt']).dt.month)

# %%
#строим графики изменений расходов по неделям и по месяцам
ax1 = plt.subplot(1, 2, 1)
(costs.pivot_table(index = 'week', columns = 'channel', values='costs', aggfunc='sum')
 .plot(ax=ax1, figsize=(13, 6), grid = True))
plt.title('Динамика расходов по неделям')
plt.xlabel('Неделя')
plt.ylabel('Затраты, $')

ax2 = plt.subplot(1, 2, 2) 
(costs.pivot_table(index = 'month', columns = 'channel', values='costs', aggfunc='sum').
 plot(ax=ax2, figsize=(13, 6), grid = True))
plt.title('Динамика расходов по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Затраты, $')

plt.tight_layout()  # «подгоняем» размер графиков, чтобы уместились подписи
plt.show();

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Отличная работа с графикой! Здорово, что есть subplots и корректное оформление графиков. В качестве рекомендаций:
# 1. Сейчас недели и месяца выделены в виде цифр - что для недель не очень удобно, поскольку мы не привыкли к такому виду; лучше использовать методы выделения месяца и недель типа datetime64;
# 2. Можно добавить единый заголовок (suptitle);
# 3. При визуализации подобных данных можно использовать графики с накоплением (они позволяют наглядно оценить вклад каждого источника + показать общее значение).
#
# Посмотри, пожалуйста, пример ниже:
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Большое спасибо за код! Добавлю plot.area себе в копилку на будущее.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# </div>

# %%
# ячейка ревьюера:
tmp = costs.copy()
tmp['month'] = tmp['dt'].astype('datetime64[M]')
tmp['week'] = tmp['dt'].astype('datetime64[W]')

#строим графики изменений расходов по неделям и по месяцам

plt.suptitle('Динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику', fontsize=14)

ax1 = plt.subplot(1, 2, 1)
(tmp.pivot_table(index = 'week', columns = 'channel', values='costs', aggfunc='sum')
 .plot.area(ax=ax1, figsize=(13, 6), grid = True))
ax1.legend(ncol=3, bbox_to_anchor=(0, -0.4), loc='lower left', borderaxespad=0)

plt.title('Динамика расходов по неделям')
plt.xlabel('Неделя')
plt.ylabel('Затраты, $')

ax2 = plt.subplot(1, 2, 2) 
(tmp.pivot_table(index = 'month', columns = 'channel', values='costs', aggfunc='sum')
 .plot.area(ax=ax2, figsize=(13, 6), grid = True))
ax2.legend(ncol=3, bbox_to_anchor=(0, -0.4), loc='lower left', borderaxespad=0)

plt.title('Динамика расходов по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Затраты, $')

plt.tight_layout()  # «подгоняем» размер графиков, чтобы уместились подписи

# зададим общее название графику: 

plt.show();

# %% [markdown]
# Из графиков видно, что расходы на каналы TipTop и FaceBoom, хоть и различаются по суммам, однако, сохраняют общую тенденцию. С мая по сентябрь наблюдается рост расходов с небольшим проседанием в июле, а с сентября расходы начинают снижаться. <br>
# По всем остальным каналам динамика расходов примерно одинаковая и сохраняется на одном уровне.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 По выводам все верно - можно еще отметить, что затраты по `TipTop` постоянно растут.
# </div>

# %% [markdown]
# Определим, сколько стоит привлечение одного пользователя из каждого источника. Исключим данные канала organic, т.к. по нему нет затрат.

# %%
(profiles.query('channel != "organic"')
 .groupby('channel')
 .agg({'acquisition_cost':'mean'})
 .sort_values(by = 'acquisition_cost', ascending = False))
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172

# %% [markdown]
# Наибольшая средняя стоимость привлечения одного пользователя для канала TipTop - ~2,8$, что объясняет высокие затраты по этому каналу в целом за все время.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 В этом блоке тоже все корректно.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 К вопросы категоризации источников - вот ниже еще пример, как можно поступить: сопоставить разные данные между собой. Например, посмотреть на средний `САС` и долю платящих - также можно выделить группу дорогих источников, которые приносят платящих пользователей, и группу дешевых с конверсией на уровне органических пользователей. Плюс есть несколько промежуточных источников. По этим группам можно потом посмотреть на общие данные по рекламной кампании (например, есть ли смысл вкладывать в дешевые источники).
#
# </div>

# %%
# ячейка ревьюера:
(profiles
 .groupby('channel')
 .agg({'acquisition_cost':'mean', 'payer' : 'mean'})
 .sort_values(by = 'acquisition_cost', ascending = False))
# Out:
#                     acquisition_cost     payer
# channel
# TipTop                      2.799003  0.096007
# FaceBoom                    1.113286  0.122049
# AdNonSense                  1.008054  0.113402
# lambdaMediaAds              0.724802  0.104700
# WahooNetBanner              0.602245  0.052964
# RocketSuperAds              0.412095  0.079137
# OppleCreativeMedia          0.250000  0.027077
# YRabbit                     0.218975  0.038265
# MediaTornado                0.218717  0.035747
# LeapBob                     0.210172  0.030633
# organic                     0.000000  0.020553

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# Проанализируем окупаемость рекламы. Рассчитаем и визуализируем LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# Пользователей из канала organic исключим, т.к. по данным пользователям нет необходимости определять окупаемость. <br>
# Так же, наличие таких пользователей, исказит расчет общих CAC и ROI по всему датасету. Расходы будут поделены между всеми пользователями, что приведет к занижению реальных значений CAC и завышению показателей окупаемости.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Условия анализа установлены верно. Здорово, что ты решила исключить органических пользователей из дальнейших исследований, поскольку компания не платила за их привлечение.
# </div>

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать следующие выводы:
# - Реклама не окупается. ROI по истечении 2 недель едва превышает 80%. Необходимо детально анализировать ROI в разрезе отдельных показателей: канала, устройства, региона;
# - Динамика LTV демонстрирует сезонность, но при этом показатель остается стабильным.
# - CAC растет. Необходимо проанализировать причины увеличения рекламного бюджета.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Все верно - мы наблюдаем увеличение стоимости привлечения пользователей, при этом, `ROI` снижается.
#
# </div>

# %% [markdown]
# Проверим конверсию и удержание пользователей, построив соответствующие графики. Пользователей канала organic исключать не будем.

# %%
# смотрим конверсию
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Пользователи конвертируются стабильно на протяжении всего цикла в 14 дней. <br>
# Конверсия пользователей на 14 день хуже всего для пользователей, зарегистрированных в середине мая. В остальные периоды конверсия характиризуется сезонными колебаниями, но можно сказать, что остается стабильной.

# %%
# смотрим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# На графиках удержания так же не выделяются явные проблемы. Удержание платящих пользователей ожидаемо выше, чем неплатящих, причем удержание платящих пользователей плавно снижается с 40% до 12,5% за весь цикл в 14 дней. Более полная картина будет получена при анализе удержания в разрезе каждого параметра (каналы, страны, устройства) в отдельности.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 В этом блоке тоже все корректно.
#
# </div>

# %% [markdown]
# Проанализуем окупаемость рекламы **в разбивке по устройствам, странам и каналам.**
#
# **1) Устройства.**

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=['device']
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Реклама окупается только для пользователей устройств PC, и происходит это стабильно. Для всех остальных устройств реклама не окупается. Самые низкий ROI у Mac и iPhone. <br>
# Проверим, с чем может быть связана данная проблема. Возможно дело не в устройствах, а в регионе или канале, откуда пришли пользователи, использующие эти устройства.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера v.1</b>
#
# 📝 В целом результаты интерпретированы верно, но обрати, пожалуйста, внимание, что мы не видим каких-то резких изменений по устройствам. Тот факт, что пользователи `Apple` имеют высокий `CAC` еще не является поводом, чтобы отказываться от этих источников - мы также помним, что у них была неплохая конверсия, а выше - хорошие значения по `LTV`. В этом случае, плохая их окупаемость может быть связаны с другими факторами. Поэтому, лучше выводы об изменениях в рекламной кампании лучше дать в конце, после того, как посмотрим все данные.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Поняла. Удалила вывод в описании выводов по проблеме и в целом вообще пока убрала отметку, что это проблема. Bold-ом подсветила только те проблемы, которые подтвердились как проблемы. <br>
# P.S. Я в целом не предлагала "урезать" под 0 бюджет для iPhone и Mac. Речь скорее про ребалансировку, чтобы часть бюджета от одних ушла к другим. Но основую идею твоего замечания я поняла - проблема этих устройств может быть вообще не в устройствах (как и оказалось ниже), поэтому рано даже называть это проблемой.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Спасибо, что скорректировала выводы и детально рассказала про свой подход. Вышло корректно :)
#
# </div>

# %%
# смотрим конверсию
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['device']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Самая низкая конверсия у пользователей PC.

# %%
# смотрим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['device']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание платящих и неплатящих пользователей для всех устройств примерно одинаковое.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Да, тут все корректно - по качеству пользователей устройства плюс-минус стабильны.
#
# </div>

# %% [markdown]
# **2) Страны.**

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=['region']
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Ранее мы проверили, что большинство пользователей приложения (2/3) - это жители США. Большой рекламный бюджет для этого региона является нормой, т.к. основная масса привлеченных пользователей из него. Однако, несмотря на это, реклама в США не окупается, ROI едва достигает 75%. Проверим, какая ситуация с конверсией и удержанием этих пользователей.
#
# При этом реклама во всех странах Европы окупилась, причем наилучший ROI демонстируют пользователи из UK - 160%. <br>
# На графике динамики ROI так же прослеживаются интересные скачки для UK в середине июля и середине августа. Возможно в эти периоды были проведены особенно успешные рекламные кампании, которые следует повторить.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Тут у меня аналогичный устройствам комментарий - возможно, мы не можем снизить рекламу на рынке `США` - поскольку эта наша целевая аудитория. Но с другой стороны, по данным видно, что происходит "прощупывание" других рынков, которые показывают неплохие результаты на фоне более низких значений по конверсии. Иными словами, мой основной посыл такой - не стоит категорично отказываться или что-то снижать, если мы видим плохие результаты - чаще важно сделать так, чтобы плохие результаты стали хорошими :)
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Поняла. Удалила вывод в описании выводов по проблеме и в целом вообще пока убрала отметку, что это проблема. Bold-ом подсветила только те проблемы, которые подтвердились как проблемы.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Спасибо!
#
# </div>

# %%
# смотрим конверсию
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['region']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия пользователей США ожидаемо выделяется, т.к. этих пользователей больше всего.

# %%
# смотрим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['region']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Проблема № 1.** <br>
# Платящие пользователи из США хуже остальных удерживаются, а ведь они основные пользователи приложения.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Да, тут еще одна проблема - плохое удержание. Нужно детально разбираться с рынком `США`.
#
# </div>

# %% [markdown]
# **3) Рекламные каналы.**

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['channel']
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **Проблема № 2.** <br>
# Реклама в 3х каналах не окупается совсем: TipTop, FaceBoom и AdNonSense. На графике CAC видно, что самые большие затраты приходятся на каналы FaceBoom и TipTop, причем затраты на TipTop превышают в несколько раз даже бюджет на FaceBoom. Проблема неокупаемости канала TipTop в том, что рекламный бюджет для него постоянно растет, при этом LTV остается более менее стабильным. Все это занижает ROI и делает вложения в TipTop неэффективными.
#
# Проверим конверсию и удержание в разрезе источников, чтобы определить, в чем может быть проблема с каналами FaceBoom и AdNonSense. Оба канала не окупаются, но CAC стабильный, LTV тоже, надо определить причину низкого ROI.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера v.1</b>
#
# ✍ Наталия, в целом был проделан большой объем работы и выводы по результатам корректны. Но, нам нужно немного детализировать исследования в этом блоке. Смотри, на стадии исследовательского анализа данных мы выделили два источника, на которые был потрачен основной бюджет рекламной кампании - это `FaceBoom` и `TipTop`.
#
# Теперь нам нужно показать, в чем именно проблемы, почему эти источники не окупаются? Если с `TipTop` все более-менее понятно - постоянно растут затраты из-за увеличения стоимости привлечения пользователя на фоне стабильного `LTV`, то вот с `FaceBoom` не до конца все ясно. В чем можем быть проблема не окупаемости? В этом нам нужно разобраться.
#
# Давай еще раз посмотрим на графики выше на источник `FaceBoom`  - `CAC` стабильный, `LTV` - в целом тоже, но `ROI` стабильно низкий. Поэтому, нам нужно посмотреть детально на конверсию и удержание по источникам. Пожалуйста, добавь это исследование и найди причину плохой окупаемости этого источника.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Удалила выводы по проблеме 4. <br>
# Добавила исследование конверсии и удержания по источникам. К сожалению, по какой-то причине просто пропустила их, хотя для устройств и регионов выше строила. <br>
# Так же скорректировала выводы, удалила упоминание о проблемах там, где проблема еще не подтверждена.
# </div>

# %% [markdown]
# Проверим конверсию и удержание по источникам.

# %%
# смотрим конверсию
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['channel']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# У каналов FaceBoom и AdNonSense конверсия в первый день жизни пользователей высокая, но довольно быстро пользователи перестают конвертироваться в платящих.

# %%
# смотрим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['channel']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Проблема №3.** <br>
# По каналам FaceBoom и AdNonSense самая плохая картина с удержанием пользователей. Следует выяснить, в чем причина.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Спасибо, что добавила дополнительные исследования. Действительно, второй по затратам источник показывает плохое удержание, на уровне неплатящих пользователей. Нужно разбираться в настройках рекламы по этому каналу. Возможно, есть пути решения этой проблемы.
#
# </div>

# %% [markdown]
# Ранее обнаружили проблему с неокупаемостью устройств iPhone и Mac. Проверим, из каких каналов привлечены пользователи этих устройств.

# %%
(profiles
 .query('channel != "organic" & device == "iPhone"')
 .pivot_table(index = 'channel', columns = 'device', values = 'user_id', aggfunc = 'count')
 .sort_values(by = 'iPhone', ascending = False)
)
# Out:
# device              iPhone
# channel
# FaceBoom             12996
# TipTop                8840
# MediaTornado          1927
# RocketSuperAds        1917
# YRabbit               1868
# WahooNetBanner        1711
# OppleCreativeMedia    1701
# LeapBob               1691
# AdNonSense             798
# lambdaMediaAds         433

# %%
(profiles.query('channel != "organic" & device == "Mac"')
 .pivot_table(index = 'channel', columns = 'device', values = 'user_id', aggfunc = 'count')
 .sort_values(by = 'Mac', ascending = False))
# Out:
# device               Mac
# channel
# FaceBoom            7265
# TipTop              4820
# RocketSuperAds      1137
# MediaTornado        1105
# YRabbit             1097
# OppleCreativeMedia   882
# LeapBob              880
# WahooNetBanner       856
# AdNonSense           410
# lambdaMediaAds       241

# %% [markdown]
# Видим, что больше половины пользователей iPhone и Mac пришли из каналов FaceBoom и TipTop, т.е. проблема неокупаемости iPhone и Mac не в затратах на рекламу для данных устройств, а в самих каналах привлечения.
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Да, получается, что устройство не является определяющим фактором.
#
# </div>
#
#
# Проверим, из каких каналов поступают пользователи США и Европы.

# %%
#считаю иногда через pivot_table, иногда через groupby, чтобы просто не забывать синтаксис
(profiles
 .query('channel != "organic" & region == "United States"')
 .groupby('channel').agg(USA_users = ('user_id','count'))
 .sort_values(by=('USA_users'), ascending=False)
)
# Out:
#                 USA_users
# channel
# FaceBoom            29144
# TipTop              19561
# RocketSuperAds       4448
# MediaTornado         4364
# YRabbit              4312

# %%
(profiles
 .query('channel != "organic" & region != "United States"')
 .groupby('channel').agg(Europe_users = ('user_id','count'))
 .sort_values(by=('Europe_users'), ascending=False)
)
# Out:
#                     Europe_users
# channel
# OppleCreativeMedia          8605
# LeapBob                     8553
# WahooNetBanner              8553
# AdNonSense                  3880
# lambdaMediaAds              2149

# %% [markdown]
# Половина пользователей из США поступила из канала FaceBoom. Это может быть одной из причин плохого удержания пользователей из США, т.к. по данному каналу в целом плохое удержание.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Все верно! Также тут хорошо видно распределение источников по региональному признаку. Теперь понятно, почему в США все плохо - там работают два проблемных источника.
#
# </div>

# %% [markdown]
# ### Напишите выводы
#
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# Результат исследования подтвердил, что реклама, направленная на привлечение пользователей, в целом не окупается.
#
# Были выявлены следующие проблемы, приведшие к убыткам компании:
# 1. Низкое удержание пользователей из США. <br>
# 2/3 пользователей приложения из США. Необходимо выяснить, с чем связано плохое удержание пользователей из США.
# Одна из возможных причин - половина пользователей США привлечены через канал FaceBoom, по которому одно из самых низких удержаний.
# 2. Чрезмерные траты на канал TipTop. <br>
# Проблема неокупаемости канала TipTop в том, что рекламный бюджет для него постоянно растет, при этом LTV остается более менее стабильным. Все это занижает ROI и делает вложения в TipTop неэффективными.
# 3. Низкое удержание пользователей из канала FaceBoom. <br>
# FaceBoom - основной канал привлечения для США. Низкое удержание, что приводит к неокупаемости этих источников.
#
#
# Рекомендации для отдела маркетинга:
# 1. Для рынка США следует выделить бюджет на другие перспективные каналы привлечения клиентов MediaTornado, YRabbit.
# 2. Следует снизить затраты на TipTop и определить причины плохого удержания по FaceBoom.
# 2. Продажи на рынке Европы показывают неплохие результаты, имеет смысл рассмотреть увеличение бюджета для данного направления.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера v.1</b>
#
# ✍ В целом итоговые выводы соответствуют полученным результатам, но отрази в них, пожалуйста, основные проблемы с источниками (про то, что я писал выше). Также, давай разберем такую ситуацию – мы не может отказать от рынка `США` в пользу других регионов, но нам нужно подправить ситуацию – какие источники на этом рынке мы можем использовать более активно?
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента v1 </b> <br>
# Исправила выводы с учетом скорректированного исследования.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Спасибо! Вопросов больше нет :)
# </div>
